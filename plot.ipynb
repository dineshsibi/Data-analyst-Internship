# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a32a1a6-d032-46f5-b64a-84cd1ca4ac6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a32a1a6-d032-46f5-b64a-84cd1ca4ac6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
factory = pd.read_csv('factory.csv')

# %%
factory.head()
# Out:
#   Factory Name         Industry  Production (Units) Labor Cost ($)  \
# 0    Factory A       Automotive               15000       2,00,000
# 1    Factory B      Electronics               12000       1,80,000
# 2    Factory C         Textiles               25000       1,50,000
# 3    Factory D  Pharmaceuticals               10000       2,20,000
# 4    Factory E        Chemicals               18000       2,10,000
#
#   Energy Cost ($) Total Cost ($)  Efficiency (%)  Downtime (Hours)
# 0          50,000       2,50,000              85               5.0
# 1          40,000       2,20,000              90               3.0
# 2          30,000       1,80,000              80               6.0
# 3          60,000       2,80,000              88               4.0
# 4          55,000       2,65,000              82               7.0

# %%
factory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Factory Name        10 non-null     object
#  1   Industry            10 non-null     object
#  2   Production (Units)  10 non-null     int64
#  3   Labor Cost ($)      10 non-null     object
#  4   Energy Cost ($)     10 non-null     object
#  5   Total Cost ($)      10 non-null     object
#  6   Efficiency (%)      10 non-null     int64
#  7   Downtime (Hours)    10 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 768.0+ bytes

# %%
sns.barplot(x='Energy Cost ($)',y='Labor Cost ($)',data=factory)
# Out:
# <Axes: xlabel='Energy Cost ($)', ylabel='Labor Cost ($)'>

# %%
sns.displot(x='Energy Cost ($)',y='Labor Cost ($)',data=factory)

# %%
sns.scatterplot(x='Energy Cost ($)',y='Labor Cost ($)',data=factory)
# Out:
# <Axes: xlabel='Energy Cost ($)', ylabel='Labor Cost ($)'>
